# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_excel('kayseri_kaza_verileri.xlsx')

# %%
# info() her sütundaki kayıt sayısı, boş veya boş olmayan veriler, Veri türü,
# veri kümesinin bellek kullanımı dahil olmak üzere veri türünü ve verilerle ilgili bilgileri anlamaya yardımcı olur
#print(data.info())

# %%
# nunique() her sütundaki birkaç benzersiz değere ve veri açıklamasına dayanarak , verilerdeki sürekli ve kategorik sütunları tanımlayabiliriz.
# Tekrarlanan veriler daha fazla analize dayalı olarak işlenebilir veya kaldırılabilir
#print(data.nunique())

# %%
# isnull(), verilerdeki boş değerleri tanımlamak için tüm ön işleme adımlarında yaygın olarak kullanılmaktadır
# data.isnull().sum() her sütundaki eksik kayıtların sayısını bulmak için kullanılır
#print(data.isnull().sum())

# %%
# Aşağıdaki kod, her sütundaki eksik değerlerin yüzdesini hesaplamaya yardımcı olur
print((data.isnull().sum()/(len(data)))*100)
# Out:
# X                          0.000000
# Y                          0.000000
# X.1                        0.000000
# Y.1                        0.000000
# KAZA TURU                  0.000000
# KGM ciddiyet seviyesi      0.000000
# Kaza Ciddiyet Seviyesi     0.000000
# AY                         0.000000
# MEVSİM                     0.000000
# KAZA SAAT                  0.177760
# MAHALLE                    0.381855
# MAHALLE yoğunluğu          0.000000
# YOL                        8.269142
# OLU SAYISI                99.473303
# YARALI SAYISI              0.243597
# TASIT SAYISI               0.079005
# SURUCU KUSURU              0.000000
# OLUS NEDENI                0.052670
# KAPLAMA CINSI              0.000000
# SERIT SAYISI               0.000000
# AYDINLATMA                 0.000000
# Unnamed: 21                0.000000
# Yasal Hız Limit            0.000000
# ARAC CINSI                 0.000000
# ARAC MODELI                0.000000
# SURUCU CINSIYET            0.000000
# SURUCU EGITIM DURUMU       0.000000
# EHLIYET YILI               0.000000
# dtype: float64

# %%
# Remove OLU SAYISI column from data
#data = data.drop(['OLU SAYISI'], axis = 1)
#print(data.info())

# %%
# Some names of the variables are not relevant and not easy to understand. Some data may have data entry errors,
# and some variables may need data type conversion. We need to fix this issue in the data.
#print(data.AY.unique())
#print(data.AY.nunique())

# %%
#describe()– Provide a statistics summary of data belonging to numerical datatype such as int, float
#print(data.describe().T)

# %%
from datetime import date
#date.today().year
#data['ARAC YILI']=date.today().year-data['ARAC MODELI']
#data.head()

# %%
data.describe().T
# Out:
#                           count          mean           std           min  \
# X                       15189.0  3.549329e+13  5.723458e+10  3.520860e+13
# Y                       15189.0  3.872819e+13  2.873429e+10  3.857290e+13
# X.1                     15189.0  3.872819e+01  2.873429e-02  3.857290e+01
# Y.1                     15189.0  3.549329e+01  5.723458e-02  3.520860e+01
# KGM ciddiyet seviyesi   15189.0  5.057871e+00  4.575804e+00  0.000000e+00
# Kaza Ciddiyet Seviyesi  15189.0  2.247021e-01  6.480300e-01  0.000000e+00
# AY                      15189.0  6.787478e+00  3.248792e+00  1.000000e+00
# KAZA SAAT               15162.0  1.424601e+01  5.588288e+00  0.000000e+00
# MAHALLE yoğunluğu       15189.0  2.391402e+00  1.036854e+00  1.000000e+00
# OLU SAYISI                 80.0  1.175000e+00  1.064680e+00  0.000000e+00
# YARALI SAYISI           15152.0  1.671463e+00  1.449626e+00  1.000000e+00
# TASIT SAYISI            15177.0  1.819134e+00  7.277052e-01  1.000000e+00
# SERIT SAYISI            15189.0  2.667325e+00  1.227698e+00  0.000000e+00
# Unnamed: 21             15189.0  2.042728e+00  3.981182e-01  1.000000e+00
# ARAC MODELI             15189.0  2.003433e+03  8.750067e+00  1.962000e+03
# EHLIYET YILI            15189.0  1.167002e+01  1.008556e+01 -6.000000e+00
#
#                                  25%           50%           75%           max
# X                       3.546004e+13  3.549359e+13  3.553521e+13  3.564494e+13
# Y                       3.871174e+13  3.872949e+13  3.874390e+13  3.882981e+13
# X.1                     3.871174e+01  3.872949e+01  3.874390e+01  3.882981e+01
# Y.1                     3.546004e+01  3.549359e+01  3.553521e+01  3.564494e+01
# KGM ciddiyet seviyesi   3.000000e+00  3.000000e+00  6.000000e+00  1.800000e+02
# Kaza Ciddiyet Seviyesi  0.000000e+00  0.000000e+00  0.000000e+00  5.000000e+00
# AY                      4.000000e+00  7.000000e+00  9.000000e+00  1.200000e+01
# KAZA SAAT               1.100000e+01  1.500000e+01  1.800000e+01  4.500000e+01
# MAHALLE yoğunluğu       2.000000e+00  2.000000e+00  3.000000e+00  4.000000e+00
# OLU SAYISI              1.000000e+00  1.000000e+00  1.000000e+00  8.000000e+00
# YARALI SAYISI           1.000000e+00  1.000000e+00  2.000000e+00  3.600000e+01
# TASIT SAYISI            1.000000e+00  2.000000e+00  2.000000e+00  2.200000e+01
# SERIT SAYISI            2.000000e+00  2.000000e+00  3.000000e+00  1.300000e+01
# Unnamed: 21             2.000000e+00  2.000000e+00  2.000000e+00  4.000000e+00
# ARAC MODELI             1.997000e+03  2.005000e+03  2.011000e+03  2.021000e+03
# EHLIYET YILI            4.000000e+00  9.000000e+00  1.800000e+01  6.100000e+01

# %%
# describe(include=’all’) provides a statistics summary of all data, include object, category etc
data.describe(include='all').T
# Out:
#                           count unique            top     freq  \
# X                       15189.0    NaN            NaN      NaN
# Y                       15189.0    NaN            NaN      NaN
# X.1                     15189.0    NaN            NaN      NaN
# Y.1                     15189.0    NaN            NaN      NaN
# KAZA TURU                 15189      2     Yaralamali    15116
# KGM ciddiyet seviyesi   15189.0    NaN            NaN      NaN
# Kaza Ciddiyet Seviyesi  15189.0    NaN            NaN      NaN
# AY                      15189.0    NaN            NaN      NaN
# MEVSİM                    15189      4            yaz     4512
# KAZA SAAT               15162.0    NaN            NaN      NaN
# MAHALLE                   15131    119        MEVLANA      787
# MAHALLE yoğunluğu       15189.0    NaN            NaN      NaN
# YOL                       13933   1583    SIVAS BULV.      781
# OLU SAYISI                 80.0    NaN            NaN      NaN
# YARALI SAYISI           15152.0    NaN            NaN      NaN
# TASIT SAYISI            15177.0    NaN            NaN      NaN
# SURUCU KUSURU             15189     79         52/1-a     3246
# OLUS NEDENI               15181     15  Yandan carpma     7009
# KAPLAMA CINSI             15189      6         Asfalt    14953
# SERIT SAYISI            15189.0    NaN            NaN      NaN
# AYDINLATMA                15189      3            Var    13940
# Unnamed: 21             15189.0    NaN            NaN      NaN
# Yasal Hız Limit         15189.0   12.0           50.0  13075.0
# ARAC CINSI                15189     19       Otomobil     7945
# ARAC MODELI             15189.0    NaN            NaN      NaN
# SURUCU CINSIYET           15189      3          ERKEK    14666
# SURUCU EGITIM DURUMU      15189     12        ILKOKUL     5339
# EHLIYET YILI            15189.0    NaN            NaN      NaN
#
#                                          mean                 std  \
# X                       35493288282324.726562  57234577833.429298
# Y                       38728185353437.648438  28734289785.588165
# X.1                                 38.728185            0.028734
# Y.1                                 35.493288            0.057235
# KAZA TURU                                 NaN                 NaN
# KGM ciddiyet seviyesi                5.057871            4.575804
# Kaza Ciddiyet Seviyesi               0.224702             0.64803
# AY                                   6.787478            3.248792
# MEVSİM                                    NaN                 NaN
# KAZA SAAT                            14.24601            5.588288
# MAHALLE                                   NaN                 NaN
# MAHALLE yoğunluğu                    2.391402            1.036854
# YOL                                       NaN                 NaN
# OLU SAYISI                              1.175             1.06468
# YARALI SAYISI                        1.671463            1.449626
# TASIT SAYISI                         1.819134            0.727705
# SURUCU KUSURU                             NaN                 NaN
# OLUS NEDENI                               NaN                 NaN
# KAPLAMA CINSI                             NaN                 NaN
# SERIT SAYISI                         2.667325            1.227698
# AYDINLATMA                                NaN                 NaN
# Unnamed: 21                          2.042728            0.398118
# Yasal Hız Limit                           NaN                 NaN
# ARAC CINSI                                NaN                 NaN
# ARAC MODELI                       2003.432945            8.750067
# SURUCU CINSIYET                           NaN                 NaN
# SURUCU EGITIM DURUMU                      NaN                 NaN
# EHLIYET YILI                        11.670024           10.085564
#
#                                      min               25%               50%  \
# X                       35208604633851.0  35460036195962.0  35493587486011.0
# Y                       38572904416144.0  38711740085304.0  38729490085335.0
# X.1                            38.572904          38.71174          38.72949
# Y.1                            35.208605         35.460036         35.493587
# KAZA TURU                            NaN               NaN               NaN
# KGM ciddiyet seviyesi                0.0               3.0               3.0
# Kaza Ciddiyet Seviyesi               0.0               0.0               0.0
# AY                                   1.0               4.0               7.0
# MEVSİM                               NaN               NaN               NaN
# KAZA SAAT                            0.0              11.0              15.0
# MAHALLE                              NaN               NaN               NaN
# MAHALLE yoğunluğu                    1.0               2.0               2.0
# YOL                                  NaN               NaN               NaN
# OLU SAYISI                           0.0               1.0               1.0
# YARALI SAYISI                        1.0               1.0               1.0
# TASIT SAYISI                         1.0               1.0               2.0
# SURUCU KUSURU                        NaN               NaN               NaN
# OLUS NEDENI                          NaN               NaN               NaN
# KAPLAMA CINSI                        NaN               NaN               NaN
# SERIT SAYISI                         0.0               2.0               2.0
# AYDINLATMA                           NaN               NaN               NaN
# Unnamed: 21                          1.0               2.0               2.0
# Yasal Hız Limit                      NaN               NaN               NaN
# ARAC CINSI                           NaN               NaN               NaN
# ARAC MODELI                       1962.0            1997.0            2005.0
# SURUCU CINSIYET                      NaN               NaN               NaN
# SURUCU EGITIM DURUMU                 NaN               NaN               NaN
# EHLIYET YILI                        -6.0               4.0               9.0
#
#                                      75%               max
# X                       35535210002099.0  35644940002083.0
# Y                       38743896384147.0  38829810085475.0
# X.1                            38.743896          38.82981
# Y.1                             35.53521          35.64494
# KAZA TURU                            NaN               NaN
# KGM ciddiyet seviyesi                6.0             180.0
# Kaza Ciddiyet Seviyesi               0.0               5.0
# AY                                   9.0              12.0
# MEVSİM                               NaN               NaN
# KAZA SAAT                           18.0              45.0
# MAHALLE                              NaN               NaN
# MAHALLE yoğunluğu                    3.0               4.0
# YOL                                  NaN               NaN
# OLU SAYISI                           1.0               8.0
# YARALI SAYISI                        2.0              36.0
# TASIT SAYISI                         2.0              22.0
# SURUCU KUSURU                        NaN               NaN
# OLUS NEDENI                          NaN               NaN
# KAPLAMA CINSI                        NaN               NaN
# SERIT SAYISI                         3.0              13.0
# AYDINLATMA                           NaN               NaN
# Unnamed: 21                          2.0               4.0
# Yasal Hız Limit                      NaN               NaN
# ARAC CINSI                           NaN               NaN
# ARAC MODELI                       2011.0            2021.0
# SURUCU CINSIYET                      NaN               NaN
# SURUCU EGITIM DURUMU                 NaN               NaN
# EHLIYET YILI                        18.0              61.0

# %%
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['KAZA TURU', 'MEVSİM', 'MAHALLE', 'YOL', 'SURUCU KUSURU', 'OLUS NEDENI',
#        'KAPLAMA CINSI', 'AYDINLATMA', 'Yasal Hız Limit', 'ARAC CINSI',
#        'SURUCU CINSIYET', 'SURUCU EGITIM DURUMU'],
#       dtype='object')
# Numerical Variables:
# ['X', 'Y', 'X.1', 'Y.1', 'KGM ciddiyet seviyesi', 'Kaza Ciddiyet Seviyesi', 'AY', 'KAZA SAAT', 'MAHALLE yoğunluğu', 'OLU SAYISI', 'YARALI SAYISI', 'TASIT SAYISI', 'SERIT SAYISI', 'Unnamed: 21', 'ARAC MODELI', 'EHLIYET YILI']

# %%
for col in num_cols:
    print(col)
    print('Skew :', round(data[col].skew(), 2))
    plt.figure(figsize = (15, 4))
    plt.subplot(1, 2, 1)
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# X
# Skew : -0.28
# Y
# Skew : -0.34
# X.1
# Skew : -0.34
# Y.1
# Skew : -0.28
# KGM ciddiyet seviyesi
# Skew : 8.86
# Kaza Ciddiyet Seviyesi
# Skew : 4.1
# AY
# Skew : -0.15
# KAZA SAAT
# Skew : -0.61
# MAHALLE yoğunluğu
# Skew : 0.26
# OLU SAYISI
# Skew : 4.22
# YARALI SAYISI
# Skew : 6.67
# TASIT SAYISI
# Skew : 3.27
# SERIT SAYISI
# Skew : 2.3
# Unnamed: 21
# Skew : 1.02
# ARAC MODELI
# Skew : -0.42
# EHLIYET YILI
# Skew : 0.96

# %%
plt.figure(figsize=(13,17))
sns.pairplot(data=data.drop(['MAHALLE yoğunluğu','EHLIYET YILI'],axis=1))
plt.show()
